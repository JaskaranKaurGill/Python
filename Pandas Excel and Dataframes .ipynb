# %%
import pandas as pd

# %%
ex1 = 'Workbook_1.xlsx'
ex2 = 'Workbook_2.xlsx'

# %%
df1 = pd.read_excel(ex1)
df2 = pd.read_excel(ex2)

# %%
df1.head()
# Out:
#         Name   Position  YR Experience  Interview Score  \
# 0      Ahmed   Engineer              3              5.0
# 1        Ben    Manager              4              4.5
# 2  Catherine    Manager              4              3.5
# 3    Derrick  Janitoral              0              0.0
# 4  Emmanuel       Sales              3              3.5
#
#                       Comments
# 0        Fantastic Preporation
# 1            Very enthusiastic
# 2  Most Professional Interview
# 3   Technologically Challenged
# 4          Awesome Sales Pitch

# %%
df2.head()
# Out:
#         Name Challenge  Group Interview Score                 Group Comments
# 0        Ben         A                      5              Kind communicator
# 1  Catherine         A                      4                 Problem solver
# 2     Felipe         A                      5                         Leader
# 3    Gabriel         B                      3  Smart at approaching problems
# 4      Jorge         B                      5                      Inspiring

# %%
df1['Name']
# Out:
# 0         Ahmed
# 1           Ben
# 2     Catherine
# 3       Derrick
# 4     Emmanuel
# 5        Felipe
# 6       Gabriel
# 7        Hassan
# 8           Ian
# 9         Jorge
# 10        Kevin
# 11        Linda
# Name: Name, dtype: object

# %%
df2['Name']
# Out:
# 0          Ben
# 1    Catherine
# 2       Felipe
# 3      Gabriel
# 4        Jorge
# 5        Kevin
# Name: Name, dtype: object

# %%
condition = df1['Name'].isin(df2['Name'])

# %%
df3 = df1.loc[condition]

# %%
df3
# Out:
#          Name          Position  YR Experience  Interview Score  \
# 1         Ben           Manager              4              4.5
# 2   Catherine           Manager              4              3.5
# 5      Felipe             Sales              4              4.0
# 6     Gabriel          Engineer              6              4.5
# 9       Jorge  Shift Supervisor              4              4.5
# 10      Kevin            Intern              5              4.0
#
#                        Comments
# 1             Very enthusiastic
# 2   Most Professional Interview
# 5                  Past success
# 6                  Captivating
# 9           Hands on experience
# 10          Impressive projects

# %%
condition = ~(df1['Name'].isin(df2['Name']))
df4 = df1.loc[condition]

# %%
df4
# Out:
#          Name          Position  YR Experience  Interview Score  \
# 0       Ahmed          Engineer              3              5.0
# 3     Derrick         Janitoral              0              0.0
# 4   Emmanuel              Sales              3              3.5
# 7      Hassan           Manager              7              5.0
# 8         Ian  Shift Supervisor              3              5.0
# 11      Linda            Intern              6              3.5
#
#                       Comments
# 0        Fantastic Preporation
# 3   Technologically Challenged
# 4          Awesome Sales Pitch
# 7                       Leader
# 8                 Well prepped
# 11                Well rounded

# %%
condition = (df1['Name'].isin(df2['Name']) & (df1['Interview Score']>4))

# %%
df5 = df1.loc[condition]

# %%
df5
# Out:
#       Name          Position  YR Experience  Interview Score  \
# 1      Ben           Manager              4              4.5
# 6  Gabriel          Engineer              6              4.5
# 9    Jorge  Shift Supervisor              4              4.5
#
#               Comments
# 1    Very enthusiastic
# 6         Captivating
# 9  Hands on experience

# %%
condition = (df1['Name'].isin(df2['Name']) & (df1['YR Experience']>3))

# %%
df6 = df1.loc[condition]

# %%
df6
# Out:
#          Name          Position  YR Experience  Interview Score  \
# 1         Ben           Manager              4              4.5
# 2   Catherine           Manager              4              3.5
# 5      Felipe             Sales              4              4.0
# 6     Gabriel          Engineer              6              4.5
# 9       Jorge  Shift Supervisor              4              4.5
# 10      Kevin            Intern              5              4.0
#
#                        Comments
# 1             Very enthusiastic
# 2   Most Professional Interview
# 5                  Past success
# 6                  Captivating
# 9           Hands on experience
# 10          Impressive projects

# %%
#merging all dataframes
all_df = pd.merge(df1, df2, how='outer', on='Name')

# %%
all_df
# Out:
#          Name          Position  YR Experience  Interview Score  \
# 0       Ahmed          Engineer              3              5.0
# 1         Ben           Manager              4              4.5
# 2   Catherine           Manager              4              3.5
# 3     Derrick         Janitoral              0              0.0
# 4   Emmanuel              Sales              3              3.5
# 5      Felipe             Sales              4              4.0
# 6     Gabriel          Engineer              6              4.5
# 7      Hassan           Manager              7              5.0
# 8         Ian  Shift Supervisor              3              5.0
# 9       Jorge  Shift Supervisor              4              4.5
# 10      Kevin            Intern              5              4.0
# 11      Linda            Intern              6              3.5
#
#                        Comments Challenge  Group Interview Score  \
# 0         Fantastic Preporation       NaN                    NaN
# ...

# %%
all_df.columns
# Out:
# Index(['Name', 'Position', 'YR Experience', 'Interview Score', 'Comments',
#        'Challenge', 'Group Interview Score', 'Group Comments'],
#       dtype='object')

# %%
condition= pd.notnull((all_df['Group Interview Score']))
new_df = all_df.loc[condition]

# %%
new_df
# Out:
#          Name          Position  YR Experience  Interview Score  \
# 1         Ben           Manager              4              4.5
# 2   Catherine           Manager              4              3.5
# 5      Felipe             Sales              4              4.0
# 6     Gabriel          Engineer              6              4.5
# 9       Jorge  Shift Supervisor              4              4.5
# 10      Kevin            Intern              5              4.0
#
#                        Comments Challenge  Group Interview Score  \
# 1             Very enthusiastic         A                    5.0
# 2   Most Professional Interview         A                    4.0
# 5                  Past success         A                    5.0
# 6                  Captivating          B                    3.0
# 9           Hands on experience         B                    5.0
# 10          Impressive projects         B                    4.0
#
#                    Group Comments
# ...

# %%
new_df.to_excel("NewWorkbook.xlsx")
# Out:
# None

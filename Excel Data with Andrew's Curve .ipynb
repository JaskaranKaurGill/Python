# %%
import pandas as pd
from pandas.plotting import andrews_curves
import matplotlib.pyplot as plt

# %%
FileName = 'CableLog.xlsx'

# %%
df = pd.read_excel(FileName)

# %%
df.head()
# Out:
#    Quality Test  Conductor Break  Jacket Fault  Jacket Bump  Average Weight  \
# 0             1                0             0            0           0.987
# 1             1                0             0            0           0.879
# 2             1                0             0            0           0.981
# 3             1                0             0            0           0.899
# 4             1                0             0            0           0.976
#
#    Average Conductivity Normalized  Jacket Shade (1 = perfect)  Cut to Length
# 0                           0.9436                         1.0           1.30
# 1                           0.9434                         1.0           1.30
# 2                           0.9432                         1.0           1.30
# 3                           0.9430                         1.0           1.25
# 4                           0.9200                         1.0           1.40

# %%
plt.figure()

# %%
andrews_curves(df, 'Quality Test')
plt.show()

# %%
plt.show()
